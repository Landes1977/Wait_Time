# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
import numpy as np
from datetime import date
from datetime import datetime

from selenium.common.exceptions import NoSuchElementException

driver = webdriver.Chrome()

url_base = 'https://wdwpassport.com/wait-times/'
# park, ride index, final hour
parks = [['magic-kingdom', 24, 22], ['epcot', 12, 21], ['hollywood-studios', 12, 21], ['animal-kingdom', 10, 20]]

# %%
# Need to test using text instead of exception.
# ------------------
def park_closed():
    try:
        down_xpath = '//*[@id="app"]/div/div/ul/li'
        driver.find_element_by_xpath(down_xpath)
    except NoSuchElementException:
        return False
    return True

# Checks if the ride is down
def check_ride_open(n):
    try:
        down_xpath = '//*[@id="app"]/div/div/ul/li['+str(n)+']/div[1]/div[1]/div'
        driver.find_element_by_xpath(down_xpath)
    except NoSuchElementException:
        return False
    return True

# Finds the ride name and wait time
def ride_wait_time(n):
    name_xpath = '//*[@id="app"]/div/div/ul/li['+str(n)+']/h3'
    time_xpath = '//*[@id="app"]/div/div/ul/li['+str(n)+']/div[1]/div/div'
    ride_name = driver.find_element_by_xpath(name_xpath)
    ride_time = driver.find_element_by_xpath(time_xpath)
    return ride_name.text, ride_time.text


# Collects the wait times 
def collect_times(url_base=url_base, parks=parks):
    wait_list = []
    for park in parks:
        if int(datetime.now().strftime("%H")) < park[2]:
            url = url_base + park[0]
            driver.get(url)
            time.sleep(1)
            if park_closed() == True:
                for n in range(2, park[1]):
                    if check_ride_open(n) == True:
                        a = ride(n)
                        wait_list+=[[date.today().strftime("%m/%d/%Y"),
                                     datetime.now().strftime("%H:%M"), 
                                     park[0], 
                                     a[0], 
                                     a[1]]]
    return wait_list

def update_file():
    times = collect_times()
    if len(times) > 0:
        df_new = pd.DataFrame(np.array(times), columns=['date', 'time', 'park', 'ride', 'wait'])
        df_old = pd.read_csv('wait_time.csv')
        df_combine = pd.concat([df_old, df_new])
        df_combine.to_csv(index=False, path_or_buf='wait_time.csv', mode='w+')

# %%
# Collects the wait times 
def collect_times(url_base=url_base, parks=parks):
    wait_list = []
    for park in parks:
        url = url_base + park[0]
        driver.get(url)
        time.sleep(1)
        if park_closed() == True: #### Needs to be Updated
            for n in range(2, park[1]):
                if check_ride_open(n) == True:
                    ride = ride_wait_time(n)
                    wait_list+=[[date.today().strftime("%m/%d/%Y"),
                                 datetime.now().strftime("%H:%M"), 
                                 park[0], 
                                 ride[0], 
                                 ride[1]]]
    return wait_list

# %%
collect_times()
# Out:
# C:\Users\Matthew Landes\anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#
# C:\Users\Matthew Landes\anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   from ipykernel import kernelapp as app
# C:\Users\Matthew Landes\anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# C:\Users\Matthew Landes\anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# [['03/06/2022', '13:35', 'magic-kingdom', 'Astro Orbiter', '50'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'The Barnstormer', '15'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   'Big Thunder Mountain Railroad',
#   '45'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   "Buzz Lightyear's Space Ranger Spin",
#   '50'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Dumbo the Flying Elephant', '35'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Haunted Mansion', '45'],
#  ['03/06/2022', '13:35', 'magic-kingdom', '"it\'s a small world"', '30'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Jungle Cruise', '60'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Mad Tea Party', '25'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   'The Magic Carpets of Aladdin',
#   '35'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   'The Many Adventures of Winnie the Pooh',
#   '40'],
#  ['03/06/2022', '13:35', 'magic-kingdom', "Mickey's PhilharMagic", '25'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Monsters Inc. Laugh Floor', '20'],
#  ['03/06/2022', '13:35', 'magic-kingdom', "Peter Pan's Flight", '45'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Pirates of the Caribbean', '60'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   'Prince Charming Regal Carrousel',
#   '15'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Seven Dwarfs Mine Train', '95'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Space Mountain', '50'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Splash Mountain', '70'],
#  ['03/06/2022', '13:35', 'magic-kingdom', 'Tomorrowland Speedway', '25'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   'Tomorrowland Transit Authority PeopleMover',
#   '30'],
#  ['03/06/2022',
#   '13:35',
#   'magic-kingdom',
#   'Under the Sea ~ Journey of The Little Mermaid',
#   '40'],
#  ['03/06/2022', '13:35', 'epcot', 'Frozen Ever After', '75'],
#  ['03/06/2022', '13:35', 'epcot', 'Gran Fiesta Tour', ''],
#  ['03/06/2022',
#   '13:35',
#   'epcot',
#   'Journey Into Imagination With Figment',
#   '10'],
#  ['03/06/2022', '13:35', 'epcot', 'Living with the Land', '20'],
#  ['03/06/2022', '13:35', 'epcot', 'Mission: SPACE', '10'],
#  ['03/06/2022', '13:35', 'epcot', "Remy's Ratatouille Adventure", '60'],
#  ['03/06/2022', '13:35', 'epcot', 'The Seas with Nemo & Friends', '15'],
#  ['03/06/2022', '13:35', 'epcot', "Soarin' Around the World", '35'],
#  ['03/06/2022', '13:35', 'epcot', 'Spaceship Earth', '5'],
#  ['03/06/2022', '13:35', 'epcot', 'Test Track', '45'],
#  ['03/06/2022', '13:35', 'hollywood-studios', 'Alien Swirling Saucers', '55'],
#  ['03/06/2022',
#   '13:35',
#   'hollywood-studios',
#   "Mickey & Minnie's Runaway Railway",
#   '60'],
#  ['03/06/2022',
#   '13:35',
#   'hollywood-studios',
#   'Millennium Falcon: Smugglers Run',
#   '75'],
#  ['03/06/2022', '13:35', 'hollywood-studios', 'Muppet*Vision 3D', '10'],
#  ['03/06/2022',
#   '13:35',
#   'hollywood-studios',
#   "Rock 'n' Roller Coaster Starring Aerosmith",
#   '90'],
#  ['03/06/2022', '13:35', 'hollywood-studios', 'Slinky Dog Dash', '90'],
#  ['03/06/2022',
#   '13:35',
#   'hollywood-studios',
#   'Star Tours – The Adventures Continue',
#   '10'],
#  ['03/06/2022',
#   '13:35',
#   'hollywood-studios',
#   'Star Wars: Rise of the Resistance',
#   '110'],
#  ['03/06/2022', '13:35', 'hollywood-studios', 'Toy Story Mania!', '65'],
#  ['03/06/2022',
#   '13:35',
#   'hollywood-studios',
#   'The Twilight Zone Tower of Terror',
#   '95'],
#  ['03/06/2022', '13:35', 'animal-kingdom', 'Avatar Flight of Passage', '80'],
#  ['03/06/2022', '13:35', 'animal-kingdom', 'DINOSAUR', '35'],
#  ['03/06/2022', '13:35', 'animal-kingdom', 'Expedition Everest', ''],
#  ['03/06/2022', '13:35', 'animal-kingdom', "It's Tough to be a Bug!", '10'],
#  ['03/06/2022', '13:35', 'animal-kingdom', 'Kali River Rapids', '40'],
#  ['03/06/2022', '13:35', 'animal-kingdom', 'Kilimanjaro Safaris', '60'],
#  ['03/06/2022', '13:35', 'animal-kingdom', "Na'vi River Journey", '80'],
#  ['03/06/2022', '13:35', 'animal-kingdom', 'TriceraTop Spin', '15']]
